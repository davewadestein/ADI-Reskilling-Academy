# %% [markdown]
# ![title](images/title.png)

# %% [markdown]
# # Logistics
# * Dave Wade-Stein (dave@developintelligence.com)
# * Class Time: 9-4 Pacific
# * Lunch: 11:45-12:30 Pacific

# %% [markdown]
# # About You and Me
# * Where are you located?
# * What is your job title/what do you do?
# * What do you want to get out of the course?
# * What's your programming/Python background?
# * Fun fact/TV show

# %% [markdown]
# # Today's Agenda
# * What? Why? Why NOT?
# * Jupyter Notebooks
# * Variables/Typing
# * Built-in Functions
# * Python Arithmetic
# * Strings
# * Indentation/syntax/code blocks
# * Controls: if, elif, and else
# * Loops
# * Lists

# %% [markdown]
# # What is Python?
# * a scripting language
# * a programming language
# * a command interpreter
# * a dynamically typed language
# * an object-oriented language

# %% [markdown]
# # Why Use Python?
# * **P**opular
# * eas**Y**
# * fas**T** (sort of)
# * pit**H**y
# * br**O**ad
# * efficie**N**t
# * plus...
#  * "batteries included"
#  * _LARGE_ community
#  * likable!

# %% [markdown]
# # Why Not Use Python?
# * CPU-bound applications can be faster in compiled languages (but not always!)
# * real-time applications
# * high-level–far from the metal

# %% [markdown]
# # Let's Get Set Up!
# * https://app.pluralsight.com/library/courses/python-data-analysts/table-of-contents
# * Open up a Terminal
# * __`git clone https://github.com/DevelopIntelligenceBoulder/Python-Fundamentals`__

# %% [markdown]
# ## How to get around in Jupyter:
# * Each place for you to enter text is called a _cell_
# * Usually you enter __`Python`__ code, but you can also enter text in a _markup_ language called __`Markdown`__ (that's what's going on in _this_ cell)
# * To "run" the code in the cell, hit __Shift-Return__ (i.e., hold down __Shift__ key, then hit __Return__)
# * Try it with the cell below...

# %%
x = 6.34
x

# %% [markdown]
# * we'll work inside the Jupyter notebook and you'll be able to take it with you as a living, breathing document of your work in this class
# * the __Insert__ menu will allow you to add a cell above or below the current cell
# * the __Kernel__ menu will allow you to "talk" to the Python interpreter on your machine
#   * (when you type into a cell, you are "talking" to the web browser, and the web browser sends the text to the __`Python`__ interpreter to be "run")
#   * the __Kernel__ menu will allow you to _restart_ your __`Python`__ interpreter in case something goes wrong and it stops responding to you

# %% [markdown]
# # The Zen of Python

# %% [markdown]
# # The Zen of Python
# * BDFL != Guido van Rossum
# * "pythonic"

# %%
import this # easter egg
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
def myfunc():
    print('hi')

# %%
id(myfunc)
# Out:
# 140218540357680

# %%
myfunc()
# Out:
# hi

# %%
id(this)
# Out:
# 140218540348912

# %%
type(this)
# Out:
# module

# %%
import math
print(id(math))
type(math)
# Out:
# 140218605517232
# module

# %%
def gamma():
    print('gamma!')

# %%
gamma()
# Out:
# gamma!

# %%
math.gamma(12)
# Out:
# 39916800.0

# %%
import antigravity
antigravity.__file__
# Out:
# '/srv/conda/envs/notebook/lib/python3.7/antigravity.py'

# %%
this.__file__ # "dunder file" is an attribute (or variable)
# Out:
# '/srv/conda/envs/notebook/lib/python3.7/this.py'

# %%
# %load '/srv/conda/envs/notebook/lib/python3.7/this.py'
s = """Gur Mra bs Clguba, ol Gvz Crgref

Ornhgvshy vf orggre guna htyl.
Rkcyvpvg vf orggre guna vzcyvpvg.
Fvzcyr vf orggre guna pbzcyrk.
Pbzcyrk vf orggre guna pbzcyvpngrq.
Syng vf orggre guna arfgrq.
Fcnefr vf orggre guna qrafr.
Ernqnovyvgl pbhagf.
Fcrpvny pnfrf nera'g fcrpvny rabhtu gb oernx gur ehyrf.
Nygubhtu cenpgvpnyvgl orngf chevgl.
Reebef fubhyq arire cnff fvyragyl.
Hayrff rkcyvpvgyl fvyraprq.
Va gur snpr bs nzovthvgl, ershfr gur grzcgngvba gb thrff.
Gurer fubhyq or bar-- naq cersrenoyl bayl bar --boivbhf jnl gb qb vg.
Nygubhtu gung jnl znl abg or boivbhf ng svefg hayrff lbh'er Qhgpu.
Abj vf orggre guna arire.
Nygubhtu arire vf bsgra orggre guna *evtug* abj.
Vs gur vzcyrzragngvba vf uneq gb rkcynva, vg'f n onq vqrn.
Vs gur vzcyrzragngvba vf rnfl gb rkcynva, vg znl or n tbbq vqrn.
Anzrfcnprf ner bar ubaxvat terng vqrn -- yrg'f qb zber bs gubfr!"""

d = {}
for c in (65, 97):
    for i in range(26):
        d[chr(i+c)] = chr((i+13) % 26 + c)

print("".join([d.get(c, c) for c in s]))
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
import string
string.__file__
# Out:
# '/srv/conda/envs/notebook/lib/python3.7/string.py'

# %%
# %load '/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/this.py'

# %%
import math
math.__file__
# Out:
# '/srv/conda/envs/notebook/lib/python3.7/lib-dynload/math.cpython-37m-x86_64-linux-gnu.so'

# %% [markdown]
# ## We will understand this code before Day 2 is over!
# * if you understand it now, you may be in the wrong class

# %%
s = '''Gur Mra bs Clguba, ol Gvz Crgref

Ornhgvshy vf orggre guna htyl.
Rkcyvpvg vf orggre guna vzcyvpvg.
Fvzcyr vf orggre guna pbzcyrk. 
Pbzcyrk vf orggre guna pbzcyvpngrq.
...'''

d = {}
for c in (65, 97):
    for i in range(26):
        d[chr(i+c)] = chr((i+13) % 26 + c)

print("".join([d.get(c, c) for c in s]))

# %% [markdown]
# # Variables/Typing

# %% [markdown]
# ## Variables/Typing
# * no declarations
# * basic data types are __int, float, string, boolean__
# * everything is an object
# * dynamically typed

# %%
x = 3
y = 24.99
print(y, x)

# %%
print(x)
x = 'Prince'
x

# %% [markdown]
# ## Strongly typed!

# %%
prince = 'Prince'

# %%
prince + 1999
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_68/2950836195.py in <module>
# ----> 1 prince + 1999
#
# TypeError: can only concatenate str (not "int") to str

# %%
prince + str(1999) # 'Prince' + '1999'
# Out:
# 'Prince1999'

# %%
i = 1
f = 1.4
b = True
s = 'True'
b = 5
s + b

# %% [markdown]
# # Some [Builtin Python Functions](https://docs.python.org/3/library/functions.html)

# %% [markdown]
# ## __`str()`__
# * returns a string containing a nicely printable representation of the object passed as its argument

# %%
str(1999)

# %%
str(True)

# %%
str(1.33e14)

# %%
str('x')

# %% [markdown]
# ## `int()`
# * returns an integer object constructed from its argument–will be an error if not a number!

# %%
x = '503'
int(x)

# %%
x += 'a' # x = x + 'a' ... '503a'
int(x)

# %% [markdown]
# ## __`type()`__
# * returns the type of the object passed as its argument

# %%
x = 1
x, type(x)

# %%
x += 0.33 # x = x + 0.33
x, type(x)

# %%
type(True)

# %% [markdown]
# ## __`print()`__
# * what does this do?

# %%
name = 'Bruce Lee'
print(name)

# %%
a, b, c = 47, -12, 19
print(a, b, c)
print(a, b, c, sep=', ') # sep is "keyword argument"

# %% [markdown]
# ## Lab: str/int/type
# *  use the Python interpreter/IDLE/Jupyter to type the following and think about the answer you expect before actually running the code
#  * if result is not what you expect, that's an opportunity for learning
#
# <pre><b>
# str(53.3)
# str(False)
# str(false)
# int('300')
# int('30x')
# type(False)
# type('False')
# type(3.5)
# </b></pre>

# %% [markdown]
# # Python Arithmetic

# %% [markdown]
# ## Python Arithmetic
# * Python interpreter can perform arithmetic similar to other languages

# %%
3 / 2

# %%
3 // 2 # "int" division

# %% [markdown]
# # div/mod/divmod

# %%
9 // 5 # "quotient"

# %%
9 % 5 # remainder when dividing 9 by 5

# %%
divmod(9, 5) # Python functions can and often do return multiple values

# %%
quot, rem = divmod(9, 5)
print(quot)
print(rem)

# %% [markdown]
# ## Python has unlimited precision integers

# %%
2 ** 20000

# %% [markdown]
# ## Fun Fact: Card Shuffling
#
# * let's use the Python interpreter as a simple calculator
# * goal is to prove that every time you shuffle a deck of cards...
#   * ...you get an ordering which is unique in human history

# %% [markdown]
# ## Floating Point Numbers
# * similar to floating point numbers in other languages
# * use __`float()`__ to convert to float, just as __`int()`__ converts to integer

# %%
x = 1
float(x)

# %%
float(True)

# %%
float('x')

# %% [markdown]
# # Strings

# %% [markdown]
# ## Strings
# * use single or double quotes
# * `\` lets you escape the next character, i.e., avoid its usual meaning

# %%
string1 = "This string isn't a problem"
string1

# %%
string2 = 'This string is a "good" example'
string2

# %%
string3 = 'This string isn\'t "more difficult" to read'
print(string3)

# %%
palindrome = 'A man,\nA plan,\nA canal:\nPanama.'
palindrome

# %%
print(palindrome)

# %% [markdown]
# * `+` = concatenation operator
# * `*` = duplication operator

# %%
s, t = "hello", 'bye' # bad practice
print(s + t)
print(s, t)

# %%
s * 4
'-' * 75

# %% [markdown]
# ## Multi-Line Strings
# * triple quotes allow for easy multi-line strings

# %%
s = '''
isn't this a
multi-line string
?
'''

s # compute the value of this expression
# Out:
# "\nisn't this a\nmulti-line string\n?\n"

# %%
print(s)
# Out:
# isn't this a
# multi-line string
# ?

# %% [markdown]
# ## Lab: Strings
# * try these...
# * ...be sure you understand what they do
#
# ```a, b, o, p = 'b', 'a', 'p', 'o'
# o + p + o
# a * 3 + b
# a + p * 2 + 'k' * 2 + 'e' * 2 + o + 'er'```

# %% [markdown]
# ## __`len()`__
# * returns the length of a string

# %%
p = 'Prince'
len(p)

# %%
len('')

# %%
len(p * 5)

# %% [markdown]
# ## Indexing Strings with __`[]`__
# * access a single character via its offset
# * easier to think of offset as opposed to index
# * negative offsets count from end of string

# %%
alphabet = 'abcdefghijklmnopqrstuvwxyz'
alphabet[0]

# %%
alphabet[25] # len(alphabet)-1

# %%
alphabet[-1] # idiomatic

# %%
alphabet[-26]

# %% [markdown]
# # Let's start writing some code!

# %%
name = input('Enter your name: ')
print('You entered', name)

# %% [markdown]
# ## Lab: shebang (Mac/Linux only)
# * using an editor (e.g., Atom, Sublime, etc.) or an IDE such as VS Code or PyCharm add the following as the first line of your Python program
#
#     __`#!/usr/bin/env python3`__
#
#
# * open a Terminal window (if you aren't already in one) and navigate to directory containing the file prog1.py and type
#
#     __`chmod +x name.py`__
#
#
# * to run it, type
#
#     __`./name.py`__

# %% [markdown]
# # Indentation

# %% [markdown]
# ## Indentation
# * colons and indentation delineate blocks {...}
# * no braces!
# * this will trip you up at first but once you're used to it, you'll love it

# %%
x = 1 # assign the value of 2 to x
if x == 1: # is x equal to 1?
    print('Hey, x is 1!')
    print('first part of if')
else:
    print('x is something other than 1')
    print('more stuff')

# %% [markdown]
# ## Indentation (continued)
# *  indentation must be consistent throughout the block

# %%
if x == 1:
    print('x is 1')
    print('something else')

# %% [markdown]
# *  you can use any indentation you want as long as it's 4 spaces (PEP-8
# https://www.python.org/dev/peps/pep-0008/)

# %% [markdown]
# # `if` statements
# * similar to if statements in other languages
# * no parens needed
# * elif = else if

# %%
my_number = 37
guess = int(input('Enter your guess: '))

if guess > my_number:
    print('Guess was too high')
elif guess < my_number:
    print('Guess was too low')
else: # my_number == guess
    print('You got it!')

# %% [markdown]
# # Comparison Operators
#
# | operator | meaning |
# |---|---|
# | == | equality  |
# | != | inequality|
# | < | less than |
# | <= | less than or equals |
# | > | greater than |
# | >= | greater than or equals |
# | in | membership |

# %%
x = 7

# %%
5 < x

# %%
x < 9

# %%
5 < x and x < 9 # &&

# %%
(5 < x) and (x < 9)

# %%
5 < x < 9
# Out:
# True

# %% [markdown]
# # Loops

# %% [markdown]
# ## Loops
# * two kinds of loops in Python
#  * __`while`__ loops ("do something until a condition becomes false")
#  * __`for`__ loops ("do something a certain number of times")

# %% [markdown]
# # `while` loop example

# %%
import random # "batteries included"
# what do you think the line below does?
my_number = random.randint(1, 100)
guess = 0 
# loop until...?

while guess != my_number:
    guess = int(input('Enter your guess (0 to give up): '))
    if guess == 0:
        print("Sorry that you're giving up!")
        break # abnormal termination
    elif guess > my_number:
        print("Guess was too high")
    elif guess < my_number:
        print("Guess was too low")        
else:
    print("Congratulations. You guessed it!")
# break would put us here

# %% [markdown]
# ## `for` loop example
# * typically used to cycle through an _iterable_ (string, list, and others we haven't learned yet) one element at a time
# * "for thing in container"

# %%
for letter in 'Python': # for each element in the container
    print(letter)

# %% [markdown]
# ## Sequences are also Iterable

# %%
for num in range(1, 10): # "for thing in container"
    print(num)

# %%
for num in range(10, 0, -1):
    print(num, end='...') 
print('blast off!')

# %%
for num in range(-5, 6): # -5 ... 5
    if num == 0:
        continue # skip the remainder of the loop, and go to next iteration
    print(1 / num, end=' ')

# %% [markdown]
# ## Quick Lab: Loops/Strings
# * have the user enter a string, then loop through the string to generate (or print) a new string in which every character is duplicated, e.g., "Python" => "PPyytthhoonn"

# %% [markdown]
# ## Lab: Loops
# * Loop through the numbers from 2 to 25 and print out which numbers are prime, and for those numbers which are not prime numbers, you should print them as a product of two factors
# * Remember that prime = no divisors other than 1 and itself
# * Don't worry about efficiency, but if you're interested, check out math.sqrt()
# * example output:
# <pre>
# 2 is a prime number
# 3 is a prime number
# 4 equals 2 * 2
# 5 is a prime number
# 6 equals 2 * 3
# 7 is a prime number
# 8 equals 2 * 4
# 9 equals 3 * 3
# 10 equals 2 * 5
# 11 is a prime number
# 12 equals 2 * 6
# 13 is a prime number
# 14 equals 2 * 7
# 15 equals 3 * 5
# 16 equals 2 * 8
# 17 is a prime number
# 18 equals 2 * 9
# 19 is a prime number
# 20 equals 2 * 10
# 21 equals 3 * 7
# 22 equals 2 * 11
# 23 is a prime number
# 24 equals 2 * 12
# 25 equals 5 * 5
# </pre>

# %% [markdown]
# ## Loops: Recap
# * __`for`__ loop is more common
# * __`break`__ exits loop immediately
# * __`continue`__ skips remainder of loop and starts next iteration
# * __`else`__ is executed if loop terminates normally (i.e., no __`break`__)

# %% [markdown]
# # Revisiting Strings

# %% [markdown]
# ## Slices
# * __`[start:stop:step]`__
# * extracts the substring from __`start`__ to __`stop`__ _minus 1_, skipping __`step`__ characters at a time
# * each of the st... are optional

# %%
alphabet = 'abcdefghijklmnopqrstuvwxyz'
         #  01234567890123456789012345 
         #                         321-

# %%
alphabet[10:15]

# %%
alphabet[:5]

# %%
alphabet[23:]

# %%
alphabet[3:23:3]

# %%
alphabet[10:2:-1]

# %%
alphabet[-3:]

# %%
alphabet[::-1] # idiomatic

# %% [markdown]
# ## More String Functions (Methods)

# %%
poem = """TWO roads diverged in a yellow wood,
And sorry I could not travel both
And be one traveler, long I stood
And looked down one as far as I could
To where it bent in the undergrowth;

Then took the other, as just as fair,
And having perhaps the better claim,
Because it was grassy and wanted wear;
Though as for that the passing there
Had worn them really about the same,

And both that morning equally lay
In leaves no step had trodden black.
Oh, I kept the first for another day!
Yet knowing how way leads on to way,
I doubted if I should ever come back.

I shall be telling this with a sigh
Somewhere ages and ages hence:
Two roads diverged in a wood, and I—
I took the one less traveled by,
And that has made all the difference."""

# %%
print(poem)
# Out:
# TWO roads diverged in a yellow wood,
# And sorry I could not travel both
# And be one traveler, long I stood
# And looked down one as far as I could
# To where it bent in the undergrowth;
#
# Then took the other, as just as fair,
# And having perhaps the better claim,
# Because it was grassy and wanted wear;
# Though as for that the passing there
# Had worn them really about the same,
#
# And both that morning equally lay
# In leaves no step had trodden black.
# Oh, I kept the first for another day!
# Yet knowing how way leads on to way,
# I doubted if I should ever come back.
#
# I shall be telling this with a sigh
# Somewhere ages and ages hence:
# Two roads diverged in a wood, and I—
# I took the one less traveled by,
# And that has made all the difference.

# %%
len(poem) # built-in function
# Out:
# 729

# %%
poem[:17]
# Out:
# 'TWO roads diverge'

# %%
poem.startswith('TWO') # startswith is a function...a "method"
# NOT startswith(poem, 'TWO')
# Out:
# True

# %%
poem.endswith('And miles to go before I sleep.')
# Out:
# False

# %%
poem.find('the')
# Out:
# 163

# %%
poem[163:178]
# Out:
# 'the undergrowth'

# %%
poem.rfind('the')
# Out:
# 714

# %%
poem.count('the')
# Out:
# 12

# %% [markdown]
# ## __`strip()`__

# %%
s = ' Now is the time      '
s.strip() # generates a new string in which leading/trailing...
# Out:
# 'Now is the time'

# %%
s
# Out:
# '\tNow is the time      '

# %%
s = '.' + s.strip() + '...'

# %%
s
# Out:
# '.Now is the time...'

# %%
s.strip('.')
# Out:
# 'Now is the time'

# %% [markdown]
# ## Even More String Functions (Methods)...

# %%
s = 'now IS the time'
s.capitalize()
# Out:
# 'Now is the time'

# %%
s.title()
# Out:
# 'Now Is The Time'

# %%
s.upper()
# Out:
# 'NOW IS THE TIME'

# %%
s.lower()
# Out:
# 'now is the time'

# %%
s.swapcase()
# Out:
# 'NOW is THE TIME'

# %%
s.replace('the', 'not the') # be careful of the naming
# Out:
# 'now IS not the time'

# %%
s.replace('t', 'T')
# Out:
# 'now IS The Time'

# %% [markdown]
# ## Lab: String Functions
# * write a Python program which prompts the user for a string and a stride (increment), and alternately makes the string upper case and lower case, stride characters at a time, e.g.,
# ![alt-text](images/uplow.png "uplow")

# %% [markdown]
# ## __`split()/join()`__

# %%
'Now is the time'.split() # this is a string method

# %%
'eggs, bread, milk, yogurt'.split(', ')

# %%
# would be nice if we could write...
# ['a', 'b', 'c'].join(' ')
# but we don't because join is a string method
''.join(['anti', 'dis', 'establish', 'men', 'tarian', 'ism'])

# %%
', '.join(['Anne', 'Robert', 'Nancy'])

# %% [markdown]
# # Lists

# %% [markdown]
# ## Lists
# * usually homogeneous, but may contain any objects
# * unbounded / not a fixed size
# * duplicates allowed
# * __`list()`__ function creates a list from another sequence or container

# %%
mylist = [1, 3, 5, 7, 5, 3, 1]
mylist

# %%
days = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
days

# %%
list('hello')

# %%
date = '12/07/1941'
date.split('/')

# %%
'a/b//c/d//e//f'.split('/')
# Out:
# ['a', 'b', '', 'c', 'd', '', 'e', '', 'f']

# %%
stuff = input('Enter something: ')

# %%
stuff.split()

# %%
cars = ['Tesla', 'Fisker', 'Rivian', 'Lordstown']

# %%
cars[0]

# %%
cars[-1] # always the last element of the list

# %%
vehicles = [cars, 'bus']
vehicles

# %%
vehicles[0]

# %%
vehicles[0][-1]

# %%
cars[-1] = 'Lordstown Motors'
cars

# %%
cars[:2] # first 2 items in a container

# %%
cars[::2] # the "evens", every other item

# %%
cars[1::2] # the "odds", every other item

# %%
cars[::-1] # also idiomatic

# %% [markdown]
# ## Looping Through a List

# %%
index = 0
while index < len(cars):
    print(cars[index])
    index += 1 # index = index + 1
# Out:
# Tesla
# Fisker
# Rivian
# Lordstown

# %%
for index in range(0, len(cars)):
    print(cars[index])
# Out:
# Tesla
# Fisker
# Rivian
# Lordstown

# %% [markdown]
# * that works, but it's not the way we'd write it in Python...it's not _Pythonic_

# %%
for car in cars: # for "thing in container"
    print(car)
# Out:
# Tesla
# Fisker
# Rivian
# Lordstown

# %% [markdown]
# ## Adding to a List ("mutator" methods)
# * __`append()`__: add an item the end of a list
# * __`insert()`__: add an item to a particular place in the list
# * __`extend()`__ (also __`+=`__): add a list to a list

# %%
cars.append('Lucid')
cars
# Out:
# ['Tesla', 'Fisker', 'Rivian', 'Lordstown', 'Lucid']

# %%
cars.insert(2, 'Faraday')
cars
# Out:
# ['Tesla', 'Fisker', 'Faraday', 'Rivian', 'Lordstown', 'Lucid']

# %%
others = ['Bollinger', 'Polestar']
cars += others # .extend()
cars
# Out:
# ['Tesla',
#  'Fisker',
#  'Faraday',
#  'Rivian',
#  'Lordstown',
#  'Lucid',
#  'Bollinger',
#  'Polestar']

# %%
cars.append(others)
cars
# Out:
# ['Tesla',
#  'Fisker',
#  'Faraday',
#  'Rivian',
#  'Lordstown',
#  'Lucid',
#  'Bollinger',
#  'Polestar',
#  ['Bollinger', 'Polestar']]

# %% [markdown]
# ## Removing from a List
# * __`del`__: delete by position
# * __`remove(item)`__: remove by value
# * __`pop()`__: remove last item (or specified item)

# %%
cars
# Out:
# ['Tesla',
#  'Fisker',
#  'Faraday',
#  'Rivian',
#  'Lordstown',
#  'Lucid',
#  'Bollinger',
#  'Polestar',
#  ['Bollinger', 'Polestar']]

# %%
del cars[-1]
cars
# Out:
# ['Tesla',
#  'Fisker',
#  'Faraday',
#  'Rivian',
#  'Lordstown',
#  'Lucid',
#  'Bollinger',
#  'Polestar']

# %%
cars.remove('Faraday')
cars
# Out:
# ['Tesla', 'Fisker', 'Rivian', 'Lordstown', 'Lucid', 'Bollinger', 'Polestar']

# %%
cars.pop() # last item by default
# Out:
# 'Bollinger'

# %%
cars

# %%
cars.pop(1) # pop() or remove the second item
# Out:
# 'Fisker'

# %%
cars
# Out:
# ['Tesla', 'Rivian', 'Lordstown', 'Lucid']

# %% [markdown]
# ## Examining Lists (inspectors)
# * __`index(item)`__: return position of item
# * __`count(item)`__: count occurrences of item
# * __`in`__: test for membership

# %%
cars
# Out:
# ['Tesla',
#  'Fisker',
#  'Faraday',
#  'Rivian',
#  'Lordstown',
#  'Lucid',
#  'Bollinger',
#  'Polestar']

# %%
if 'Lucidity' in cars:
    print(cars.index('Lucidity')) # if this returned -1 we could mistake it for a valid index, i.e., last item

# %%
'Rivians' in cars
# Out:
# False

# %%
'Lordstown' in cars
# Out:
# True

# %%
for count in range(10): # do something 10 times
    cars.append('Byton')

# %%
cars
# Out:
# ['Tesla',
#  'Rivian',
#  'Lordstown',
#  'Lucid',
#  'Byton',
#  'Byton',
#  'Byton',
#  'Byton',
#  'Byton',
#  'Byton',
#  'Byton',
#  'Byton',
#  'Byton',
#  'Byton']

# %%
cars.count('Byton')
# Out:
# 10

# %%
while 'Byton' in cars:
    cars.remove('Byton') # each call only removes one
cars
# Out:
# ['Tesla', 'Rivian', 'Lordstown', 'Lucid']

# %%
for times in range(cars.count('Byton')): # do this loop 10 times
    cars.remove('Byton')
cars
# Out:
# ['Tesla', 'Rivian', 'Lordstown', 'Lucid']

# %% [markdown]
# ## __`join()/split()`__–redux

# %%
cars
# Out:
# ['Tesla', 'Rivian', 'Lordstown', 'Lucid']

# %%
joined = ', '.join(cars)
joined # string which represents the "joined" items in the list
# Out:
# 'Tesla, Rivian, Lordstown, Lucid'

# %%
unjoined = joined.split(', ')
unjoined # split into a new list
# Out:
# ['Tesla', 'Rivian', 'Lordstown', 'Lucid']

# %%
cars == unjoined # are they the same? (They should be...)
# Out:
# True

# %% [markdown]
# ## Sorting Lists
# * __`sort()`__: _method_ to sort a list in place
# * __`sorted()`__: _built-in function_ which returns a sorted list created
# from an iterable/sequence
# * __`len()`__: returns length of a list

# %%
print(cars, id(cars))
# Out:
# ['Tesla', 'Rivian', 'Lordstown', 'Lucid'] 140638511129856

# %%
cars.sort() # mutator method which sorts the list
print(cars, id(cars))
# Out:
# ['Lordstown', 'Lucid', 'Rivian', 'Tesla'] 140638511129856

# %%
cars.sort(reverse=True)
print(cars, id(cars))
# Out:
# ['Tesla', 'Rivian', 'Lucid', 'Lordstown'] 140638511129856

# %%
# built-in function which can't mutate the list
sorted_list = sorted(cars) 
print(sorted_list, id(sorted_list), id(cars))
# Out:
# ['Lordstown', 'Lucid', 'Rivian', 'Tesla'] 140638511111456 140638511129856

# %%
cars = cars.sort() # take the value returned by the function and put it into cars...

# %%
print(cars)
# Out:
# None

# %%
help(list.sort)
# Out:
# Help on method_descriptor:
#
# sort(self, /, *, key=None, reverse=False)
#     Stable sort *IN PLACE*.

# %%
thing = print('this is a legit Python statement')
print(thing)
# Out:
# this is a legit Python statement
# None

# %%
s = 'this is not terminated
# Out:
#   File "/tmp/ipykernel_87/4056302467.py", line 1
#     s = 'this is not terminated
#                                ^
# SyntaxError: EOL while scanning string literal

# %%
new_list = '1 2 3 1 2 3 1 1 1 1'.split()
new_list
# Out:
# ['1', '2', '3', '1', '2', '3', '1', '1', '1', '1']

# %%
count = new_list.count('1')
count
# Out:
# 6

# %%
    list.
# Out:
# Help on method_descriptor:
#
# copy(self, /)
#     Return a shallow copy of the list.

# %% [markdown]
# # List assignment does not copy the values!
# * use __`copy()`__, __`list()`__, or __`[:]`__ to copy the values
# * we'll use __`pythontutor.com`__ to understand the difference

# %%
cars

# %%
c = cars
c[2] = 'Lordstown Motors'
cars

# %%
c = cars.copy()
c[2] = 'Lordstown'
cars

# %%
c

# %%
c = list(cars)
c

# %%
c = cars[:]
c

# %% [markdown]
# * Write a Python program to read in a list of items possibly containing duplicates, and then constructs a new list which contains the elements from the original list, with the order preserved, but the duplicates removed

# %%
# 1a. read a line of input
# 1b. turn it into a list (.split()) ... split a string into a list
# 2. create a new (empty) list to hold the non-dupes
# 3. for each word in the original list:
#    4. if word is not in the new list:
#         5. add it to the new list
words = input('Enter some words and I will abracadabra: ').split() # 1a and 1b
# Out:
# Enter some words and I will abracadabra:  apple cherry banana lemon cherry apple lime banana

# %%
words # check our work
# Out:
# ['apple', 'cherry', 'banana', 'lemon', 'cherry', 'apple', 'lime', 'banana']

# %%
non_dupe_words = [] # step 2
for word in words: # step 3
    if word not in non_dupe_words: # step 4
        non_dupe_words.append(word) # step 5

non_dupe_words
# Out:
# ['apple', 'cherry', 'banana', 'lemon', 'lime']

# %% [markdown]
# ## Lab: Lists
# * Write a Python program to maintain a list
#   * Read input until the user enters 'quit'
#   * For each word:
#     * If a word begins with '-' (e.g., '-foo') it should be removed from the list
#     * If the user enters only a '-', the list should be reversed
#     * Words that the user enters should be added to the list
#   * After each operation, print the list
#   * Extras:
#       * If user enters more than one word (e.g, __foo bar__), add "foo" and "bar" to the list, rather than "foo bar"
#       * Same for "-", i.e., __-foo bar__ would remove "foo" and "bar" from the  list

# %%
# 0. create an empty list
# 1. read words from the keyboard until 'quit'
# 2. if word begins with '-', remove it from the list
#    2a. (extra) split up the words on the line and remove each individually
# 3. if the word is '-', reverse the list
# 4. otherwise, add the word to the list
#.   4a. (extra) split the line into words and add each word to the list
# 5. print the list

# %%
# first cut, we can do better...
# 1. no error checking
# 2. what if user just hits return?
# 3. add additional extras from above
list_of_words = []

while True: # step 1...
    word = input('Enter a word: ')
    if word == 'quit':
        break # also step 1
    # step 2...
    if word.startswith('-'): # - is the first letter
        if word == '-': # ...and in fact the only letter
            # step 3
            list_of_words = list_of_words[::-1] # .reverse() is perhaps better
        else: # begins with -, but not just a -
            # also step 2
            list_of_words.remove(word[1:]) # ignore '-', as it's not part of the word
    else: # does not start with -, so step 4
        list_of_words.append(word)
    print(list_of_words)
# Out:
# Enter a word:  quit

# %%
# second cut

list_of_words = []

while True: # step 1...
    response = input('Enter a word: ')
    if not response: # response == ''
        continue
    if response == 'quit':
        break # also step 1
    # step 2...
    if response.startswith('-'): # - is the first letter
        if response == '-': # ...and in fact the only letter
            # step 3
            if len(list_of_words) < 2:
                print('Hey, trying to reverse fewer than 2 items is moon man talk!')
            else:
                list_of_words = list_of_words[::-1] # .reverse() is perhaps better
        else: # begins with -, but not just a -
            # also step 2
            for word in response[1:].split(): # split everything AFTER the hyphen/dash/minus
                if word in list_of_words:
                    list_of_words.remove(word) # ignore '-', as it's not part of the word
                else:
                    print(f'Pay attention! "{word}" is not in the list!')          
    else: # does not start with -, so step 4
        words = response.split() # list of 1+ or more words
        list_of_words.extend(words)
    print(list_of_words)
# Out:
# Enter a word:  -
# Hey, trying to reverse fewer than 2 items is moon man talk!
# []
# Enter a word:  apple
# ['apple']
# Enter a word:  -
# Hey, trying to reverse fewer than 2 items is moon man talk!
# ['apple']
# Enter a word:  foo
# ['apple', 'foo']
# Enter a word:  -
# ['foo', 'apple']
# Enter a word:  quit

# %% [markdown]
# # End of Day 1

# %%
'-foo bar baz'.split()
# Out:
# ['-foo', 'bar', 'baz']
